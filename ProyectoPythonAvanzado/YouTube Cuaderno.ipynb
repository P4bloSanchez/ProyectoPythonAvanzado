# %% [markdown]
# # Extracción de Datos con YouTube API

# %% [markdown]
# ## Instalacion de la API de Youtube

# %%
pip install --upgrade google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (2.117.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (2.16.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.23.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pablosanchez/anaconda3/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Instalación de los paquetes

# %%
from googleapiclient.discovery import build
from datetime import datetime
import Cuenta

# %% [markdown]
# ## Accediendo a YouTube con la clave del API

# %%
youtube = build('youtube','v3',developerKey = Cuenta.getClave())

# %% [markdown]
# ## Extrayendo datos del canal

# %% [markdown]
# ### El canal al cuál se le van a extraer datos es este:

# %% [markdown]
# ![Imagén del canal](Canal.jpg)

# %%
solicitud = youtube.channels().list(
    part='statistics',
    forHandle = '@historiasdeaves'
)
datosDelCanal = solicitud.execute()
datosDelCanal
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'KzKd1Bp_-MKtSka0hnviDgz2QiU',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'jtqxTwuZlFJwslbGenmoRNbR_Yc',
#    'id': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'statistics': {'viewCount': '782077',
#     'subscriberCount': '12500',
#     'hiddenSubscriberCount': False,
#     'videoCount': '444'}}]}

# %% [markdown]
# ##### Nota: He usado el parametro "forHandle" en vez del "forUsername" debido a que usando este último no daba la información requerida.

# %% [markdown]
# ## Extracción del ID del canal

# %%
idCanal = datosDelCanal['items'][0]['id']
idCanal
# Out:
# 'UCj6Y19iGJGLQdg0bPKM8l1A'

# %% [markdown]
# ## Extracción de la información de los datos de las listas de reproducción del canal

# %%
listasDelCanal = youtube.playlists().list(
    part = 'contentDetails,snippet', #Datos de contenido de la listas de reproduccion
    channelId = idCanal,
    maxResults=200 #Maximo resultados. Si hay más de 200 solo mostrará 200 resultados
)
resultadoListas = listasDelCanal.execute()
resultadoListas
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'NQ-d6jliUEyZKfCqWVxpn50xei4',
#  'pageInfo': {'totalResults': 14, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'ovIrPkhSsh0fIWkDL_5_7j7b0SE',
#    'id': 'PLxZAFzB1EbZaaBOsL2pyDc7jCOiOiTCey',
#    'snippet': {'publishedAt': '2023-05-15T19:14:23Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a los Colibríes',
#     'description': 'Aquí tienes todos los vídeos relacionados con los colibríes (Familia Trochilidae) y sus increíbles historias',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a los Colibríes',
#      'description': 'Aquí tienes todos los vídeos relacionados con los colibríes (Familia Trochilidae) y sus increíbles historias'}},
#    'contentDetails': {'itemCount': 21}},
#   {'kind': 'youtube#playlist',
#    'etag': 'mkGfOrVsPDa1rxpVJFAzwqnL_uM',
#    'id': 'PLxZAFzB1EbZY0DHDxcj8UcRte9CuqYM30',
#    'snippet': {'publishedAt': '2022-01-04T03:24:22Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Binoculares para la observación de aves - La Mochila Pajarera',
#     'description': 'En esta lista de reproducción encontraras las reviews de distintos elementos de equipo para observar aves',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Binoculares para la observación de aves - La Mochila Pajarera',
#      'description': 'En esta lista de reproducción encontraras las reviews de distintos elementos de equipo para observar aves'}},
#    'contentDetails': {'itemCount': 13}},
#   {'kind': 'youtube#playlist',
#    'etag': 'DzzKKsYipiAZeTgsHd6sCZDqm_A',
#    'id': 'PLxZAFzB1EbZaVwUo6N5foohmHNVZ3bbCq',
#    'snippet': {'publishedAt': '2021-03-10T23:48:50Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a los Chipes y Reinitas',
#     'description': 'En esta lista de reproducción encontrarás todos los videos referentes a los chipes y las reinitas (familia Parulidae)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a los Chipes y Reinitas',
#      'description': 'En esta lista de reproducción encontrarás todos los videos referentes a los chipes y las reinitas (familia Parulidae)'}},
#    'contentDetails': {'itemCount': 13}},
#   {'kind': 'youtube#playlist',
#    'etag': 'PmQdPYGlRqTNZz0_l0z_jXvbyvk',
#    'id': 'PLxZAFzB1EbZai_izWRKCAWaOOzt3f9_h0',
#    'snippet': {'publishedAt': '2020-12-08T01:40:33Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a las Aves Rapaces',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a las Aves Rapaces',
#      'description': ''}},
#    'contentDetails': {'itemCount': 18}},
#   {'kind': 'youtube#playlist',
#    'etag': '9tgWZy_X5YBe9dR4X47OurmbHz4',
#    'id': 'PLxZAFzB1EbZbgZOxYdlbx16R79vO6Azjc',
#    'snippet': {'publishedAt': '2020-11-07T18:34:11Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Hablemos de Aves (directos)',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Hablemos de Aves (directos)', 'description': ''}},
#    'contentDetails': {'itemCount': 67}},
#   {'kind': 'youtube#playlist',
#    'etag': 'xJEaB_w0orxzdmrvy8vibAtpe5s',
#    'id': 'PLxZAFzB1EbZZpaDQBL6LWhCmzXL9qam4-',
#    'snippet': {'publishedAt': '2020-10-11T00:57:30Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo sobre la migración',
#     'description': 'Hola! En esta lista de reproducción encontrarás vídeos que te servirán para conocer un poco sobre el fenómeno de la migración en las aves',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo sobre la migración',
#      'description': 'Hola! En esta lista de reproducción encontrarás vídeos que te servirán para conocer un poco sobre el fenómeno de la migración en las aves'}},
#    'contentDetails': {'itemCount': 6}},
#   {'kind': 'youtube#playlist',
#    'etag': 'WxlPcg61hBCMbwDT7XtMfRJuG2Y',
#    'id': 'PLxZAFzB1EbZa18JnhuJT5CGVYF5qkd1lZ',
#    'snippet': {'publishedAt': '2020-08-09T19:07:57Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a los Mosqueros',
#     'description': 'En esta lista de reproducción encontrarás vídeos para saber más sobre las aves de las familias Tyrannidae y Oxyruncidae',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a los Mosqueros',
#      'description': 'En esta lista de reproducción encontrarás vídeos para saber más sobre las aves de las familias Tyrannidae y Oxyruncidae'}},
#    'contentDetails': {'itemCount': 17}},
#   {'kind': 'youtube#playlist',
#    'etag': 'CJ-Wta_0xwNrNwcM9jjG55htpp4',
#    'id': 'PLxZAFzB1EbZY4e9FRlDjLd0zCo0ldb267',
#    'snippet': {'publishedAt': '2020-06-08T16:21:44Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a los Gorriones',
#     'description': 'En esta lista de reproducción encontrarás información acerca de los Gorriones del nuevo mundo (Passerelidae) y sus historias pequeñas',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a los Gorriones',
#      'description': 'En esta lista de reproducción encontrarás información acerca de los Gorriones del nuevo mundo (Passerelidae) y sus historias pequeñas'}},
#    'contentDetails': {'itemCount': 10}},
#   {'kind': 'youtube#playlist',
#    'etag': 'zsz2zsGT7GrrUO_nlmUWysfSziY',
#    'id': 'PLxZAFzB1EbZZ6wMbDkUKXPS-z3gT9Zbk0',
#    'snippet': {'publishedAt': '2020-05-31T21:35:04Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a los Pájaros Carpinteros',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a los Pájaros Carpinteros',
#      'description': ''}},
#    'contentDetails': {'itemCount': 10}},
#   {'kind': 'youtube#playlist',
#    'etag': 'k5ZEi-vvFfmAIPU1hQk5D9tzMlE',
#    'id': 'PLxZAFzB1EbZa5aZmsMj_lXXwsdD2rpygY',
#    'snippet': {'publishedAt': '2020-02-18T02:59:53Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'CONSEJOS para Aprender a Observar Aves [Tips para la Observación de las Aves]',
#     'description': 'Si eres un amante de la naturaleza o simplemente deseas adentrarte en el fascinante mundo del avistamiento de aves, estás en el lugar adecuado. Aquí encontrarás una colección de videos repletos de consejos prácticos, técnicas esenciales de identificación y estrategias sencillas y expertas para convertirte en un observador de aves.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'CONSEJOS para Aprender a Observar Aves [Tips para la Observación de las Aves]',
#      'description': 'Si eres un amante de la naturaleza o simplemente deseas adentrarte en el fascinante mundo del avistamiento de aves, estás en el lugar adecuado. Aquí encontrarás una colección de videos repletos de consejos prácticos, técnicas esenciales de identificación y estrategias sencillas y expertas para convertirte en un observador de aves.'}},
#    'contentDetails': {'itemCount': 11}},
#   {'kind': 'youtube#playlist',
#    'etag': 'J-fFLH_VpoNFZE7hE3FRW-XjrVw',
#    'id': 'PLxZAFzB1EbZboAbGpIBs41CFNtTY_fW05',
#    'snippet': {'publishedAt': '2019-09-09T22:43:45Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a las Aves Playeras',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a las Aves Playeras',
#      'description': ''}},
#    'contentDetails': {'itemCount': 27}},
#   {'kind': 'youtube#playlist',
#    'etag': 'FNNVYg40GqPKJV-wwgRC-xzHK90',
#    'id': 'PLxZAFzB1EbZb4XtfzZg20VyAbqbO_S3O8',
#    'snippet': {'publishedAt': '2019-08-04T21:10:31Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Conociendo a los Búhos',
#     'description': 'En esta lista de reproducción encontrarás vídeos referentes a los Strigiformes (Búhos y Lechuzas)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Conociendo a los Búhos',
#      'description': 'En esta lista de reproducción encontrarás vídeos referentes a los Strigiformes (Búhos y Lechuzas)'}},
#    'contentDetails': {'itemCount': 14}},
#   {'kind': 'youtube#playlist',
#    'etag': '2XcBkSxoK2vwIzyPq1BuNo0SsCQ',
#    'id': 'PLxZAFzB1EbZYEmiUWnhDL04n7xypjz2yl',
#    'snippet': {'publishedAt': '2018-02-18T02:57:10Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Un minuto de aves',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Un minuto de aves', 'description': ''}},
#    'contentDetails': {'itemCount': 199}},
#   {'kind': 'youtube#playlist',
#    'etag': 'd15Qld7n3udkOXGc6ds4zMZ6k6s',
#    'id': 'PLxZAFzB1EbZbOtlVV22wB59w9SuhHcXpG',
#    'snippet': {'publishedAt': '2017-12-26T23:53:54Z',
#     'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#     'title': 'Pajareando en:',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#     'localized': {'title': 'Pajareando en:', 'description': ''}},
#    'contentDetails': {'itemCount': 13}}]}

# %%
totalPlaylist = []

# %%
while listasDelCanal is not None: #Simpre y cuando no sean nulas.
    play_list_result = listasDelCanal.execute()
    totalPlaylist += play_list_result['items']
    listasDelCanal = youtube.playlists().list_next(listasDelCanal, resultadoListas)

#Total de listas de reproduccion
print(f"Total: {len(totalPlaylist)}")
# Out:
# Total: 14

# %%
totalPlaylist
# Out:
# [{'kind': 'youtube#playlist',
#   'etag': 'ovIrPkhSsh0fIWkDL_5_7j7b0SE',
#   'id': 'PLxZAFzB1EbZaaBOsL2pyDc7jCOiOiTCey',
#   'snippet': {'publishedAt': '2023-05-15T19:14:23Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a los Colibríes',
#    'description': 'Aquí tienes todos los vídeos relacionados con los colibríes (Familia Trochilidae) y sus increíbles historias',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/jU5IOmPnfLo/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a los Colibríes',
#     'description': 'Aquí tienes todos los vídeos relacionados con los colibríes (Familia Trochilidae) y sus increíbles historias'}},
#   'contentDetails': {'itemCount': 21}},
#  {'kind': 'youtube#playlist',
#   'etag': 'mkGfOrVsPDa1rxpVJFAzwqnL_uM',
#   'id': 'PLxZAFzB1EbZY0DHDxcj8UcRte9CuqYM30',
#   'snippet': {'publishedAt': '2022-01-04T03:24:22Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Binoculares para la observación de aves - La Mochila Pajarera',
#    'description': 'En esta lista de reproducción encontraras las reviews de distintos elementos de equipo para observar aves',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/RN6un44Z0HA/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Binoculares para la observación de aves - La Mochila Pajarera',
#     'description': 'En esta lista de reproducción encontraras las reviews de distintos elementos de equipo para observar aves'}},
#   'contentDetails': {'itemCount': 13}},
#  {'kind': 'youtube#playlist',
#   'etag': 'DzzKKsYipiAZeTgsHd6sCZDqm_A',
#   'id': 'PLxZAFzB1EbZaVwUo6N5foohmHNVZ3bbCq',
#   'snippet': {'publishedAt': '2021-03-10T23:48:50Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a los Chipes y Reinitas',
#    'description': 'En esta lista de reproducción encontrarás todos los videos referentes a los chipes y las reinitas (familia Parulidae)',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/OikYK0QCnnk/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a los Chipes y Reinitas',
#     'description': 'En esta lista de reproducción encontrarás todos los videos referentes a los chipes y las reinitas (familia Parulidae)'}},
#   'contentDetails': {'itemCount': 13}},
#  {'kind': 'youtube#playlist',
#   'etag': 'PmQdPYGlRqTNZz0_l0z_jXvbyvk',
#   'id': 'PLxZAFzB1EbZai_izWRKCAWaOOzt3f9_h0',
#   'snippet': {'publishedAt': '2020-12-08T01:40:33Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a las Aves Rapaces',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/dZgbzB1AbiQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a las Aves Rapaces', 'description': ''}},
#   'contentDetails': {'itemCount': 18}},
#  {'kind': 'youtube#playlist',
#   'etag': '9tgWZy_X5YBe9dR4X47OurmbHz4',
#   'id': 'PLxZAFzB1EbZbgZOxYdlbx16R79vO6Azjc',
#   'snippet': {'publishedAt': '2020-11-07T18:34:11Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Hablemos de Aves (directos)',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/7yIggKQF6SQ/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Hablemos de Aves (directos)', 'description': ''}},
#   'contentDetails': {'itemCount': 67}},
#  {'kind': 'youtube#playlist',
#   'etag': 'xJEaB_w0orxzdmrvy8vibAtpe5s',
#   'id': 'PLxZAFzB1EbZZpaDQBL6LWhCmzXL9qam4-',
#   'snippet': {'publishedAt': '2020-10-11T00:57:30Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo sobre la migración',
#    'description': 'Hola! En esta lista de reproducción encontrarás vídeos que te servirán para conocer un poco sobre el fenómeno de la migración en las aves',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/BOBPnuyRpnU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo sobre la migración',
#     'description': 'Hola! En esta lista de reproducción encontrarás vídeos que te servirán para conocer un poco sobre el fenómeno de la migración en las aves'}},
#   'contentDetails': {'itemCount': 6}},
#  {'kind': 'youtube#playlist',
#   'etag': 'WxlPcg61hBCMbwDT7XtMfRJuG2Y',
#   'id': 'PLxZAFzB1EbZa18JnhuJT5CGVYF5qkd1lZ',
#   'snippet': {'publishedAt': '2020-08-09T19:07:57Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a los Mosqueros',
#    'description': 'En esta lista de reproducción encontrarás vídeos para saber más sobre las aves de las familias Tyrannidae y Oxyruncidae',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/oW7CGnLH3cM/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a los Mosqueros',
#     'description': 'En esta lista de reproducción encontrarás vídeos para saber más sobre las aves de las familias Tyrannidae y Oxyruncidae'}},
#   'contentDetails': {'itemCount': 17}},
#  {'kind': 'youtube#playlist',
#   'etag': 'CJ-Wta_0xwNrNwcM9jjG55htpp4',
#   'id': 'PLxZAFzB1EbZY4e9FRlDjLd0zCo0ldb267',
#   'snippet': {'publishedAt': '2020-06-08T16:21:44Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a los Gorriones',
#    'description': 'En esta lista de reproducción encontrarás información acerca de los Gorriones del nuevo mundo (Passerelidae) y sus historias pequeñas',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a los Gorriones',
#     'description': 'En esta lista de reproducción encontrarás información acerca de los Gorriones del nuevo mundo (Passerelidae) y sus historias pequeñas'}},
#   'contentDetails': {'itemCount': 10}},
#  {'kind': 'youtube#playlist',
#   'etag': 'zsz2zsGT7GrrUO_nlmUWysfSziY',
#   'id': 'PLxZAFzB1EbZZ6wMbDkUKXPS-z3gT9Zbk0',
#   'snippet': {'publishedAt': '2020-05-31T21:35:04Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a los Pájaros Carpinteros',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/F0ri6AoFNkc/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a los Pájaros Carpinteros',
#     'description': ''}},
#   'contentDetails': {'itemCount': 10}},
#  {'kind': 'youtube#playlist',
#   'etag': 'k5ZEi-vvFfmAIPU1hQk5D9tzMlE',
#   'id': 'PLxZAFzB1EbZa5aZmsMj_lXXwsdD2rpygY',
#   'snippet': {'publishedAt': '2020-02-18T02:59:53Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'CONSEJOS para Aprender a Observar Aves [Tips para la Observación de las Aves]',
#    'description': 'Si eres un amante de la naturaleza o simplemente deseas adentrarte en el fascinante mundo del avistamiento de aves, estás en el lugar adecuado. Aquí encontrarás una colección de videos repletos de consejos prácticos, técnicas esenciales de identificación y estrategias sencillas y expertas para convertirte en un observador de aves.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/UejlJwt9zWM/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'CONSEJOS para Aprender a Observar Aves [Tips para la Observación de las Aves]',
#     'description': 'Si eres un amante de la naturaleza o simplemente deseas adentrarte en el fascinante mundo del avistamiento de aves, estás en el lugar adecuado. Aquí encontrarás una colección de videos repletos de consejos prácticos, técnicas esenciales de identificación y estrategias sencillas y expertas para convertirte en un observador de aves.'}},
#   'contentDetails': {'itemCount': 11}},
#  {'kind': 'youtube#playlist',
#   'etag': 'J-fFLH_VpoNFZE7hE3FRW-XjrVw',
#   'id': 'PLxZAFzB1EbZboAbGpIBs41CFNtTY_fW05',
#   'snippet': {'publishedAt': '2019-09-09T22:43:45Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a las Aves Playeras',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/QhX4hYCOoJw/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a las Aves Playeras',
#     'description': ''}},
#   'contentDetails': {'itemCount': 27}},
#  {'kind': 'youtube#playlist',
#   'etag': 'FNNVYg40GqPKJV-wwgRC-xzHK90',
#   'id': 'PLxZAFzB1EbZb4XtfzZg20VyAbqbO_S3O8',
#   'snippet': {'publishedAt': '2019-08-04T21:10:31Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Conociendo a los Búhos',
#    'description': 'En esta lista de reproducción encontrarás vídeos referentes a los Strigiformes (Búhos y Lechuzas)',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Bg5l8ax7Kfc/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Conociendo a los Búhos',
#     'description': 'En esta lista de reproducción encontrarás vídeos referentes a los Strigiformes (Búhos y Lechuzas)'}},
#   'contentDetails': {'itemCount': 14}},
#  {'kind': 'youtube#playlist',
#   'etag': '2XcBkSxoK2vwIzyPq1BuNo0SsCQ',
#   'id': 'PLxZAFzB1EbZYEmiUWnhDL04n7xypjz2yl',
#   'snippet': {'publishedAt': '2018-02-18T02:57:10Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Un minuto de aves',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/uEvzPjNUGMc/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Un minuto de aves', 'description': ''}},
#   'contentDetails': {'itemCount': 199}},
#  {'kind': 'youtube#playlist',
#   'etag': 'd15Qld7n3udkOXGc6ds4zMZ6k6s',
#   'id': 'PLxZAFzB1EbZbOtlVV22wB59w9SuhHcXpG',
#   'snippet': {'publishedAt': '2017-12-26T23:53:54Z',
#    'channelId': 'UCj6Y19iGJGLQdg0bPKM8l1A',
#    'title': 'Pajareando en:',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/VQs3XW8E_NI/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Crónicas del Chivizcoyo (historias de aves)',
#    'localized': {'title': 'Pajareando en:', 'description': ''}},
#   'contentDetails': {'itemCount': 13}}]

# %%
print(totalPlaylist[1]['id'])
print(totalPlaylist[1]['snippet']['title'])
# Out:
# PLxZAFzB1EbZY0DHDxcj8UcRte9CuqYM30
# Binoculares para la observación de aves - La Mochila Pajarera

# %%
def timestream(time):
    time = time.replace("T","").replace("Z","") #Quitamos la T y Z del string
    date,hour = time[0:10],time[11:21] #separamos entre fecha y hora
    time = '{} {}'.format(date ,hour) #Lo concatenamos en una forma diferente
    datetime_object = datetime.strptime(time, "%Y-%m-%d %H:%M:%S") #Aplicamos una funcion de datetime para convertirlo en formato de hora
    return datetime_object #Retornamos la hora del objeto

# %%
#En este apartado vamos a obtener varias cosas como:
# ID, titulo de la lista de reproduccion, No. Canciones, Fecha, la imagen de portada de la lista de reproduccion
from datetime import datetime
playlist_ids = []
playlist_name = []
playlist_pictureStandard = []
playlist_timepublish = []
playlist_noVideos = []
for j in range(0,len(totalPlaylist)):
    playlist_ids.append(totalPlaylist[j]['id'])
    playlist_name.append(totalPlaylist[j]['snippet']['title'])
    playlist_pictureStandard.append(totalPlaylist[j]['snippet']['thumbnails']['standard']['url'])
    playlist_timepublish.append(timestream(totalPlaylist[j]['snippet']['publishedAt'])) #Aqui aplicamos nuestra funcion para tener un objeto datetime
    playlist_noVideos.append(totalPlaylist[j]['contentDetails']['itemCount'])

# %%
for i in playlist_name:
    print(i)
# Out:
# Conociendo a los Colibríes
# Binoculares para la observación de aves - La Mochila Pajarera
# Conociendo a los Chipes y Reinitas
# Conociendo a las Aves Rapaces
# Hablemos de Aves (directos)
# Conociendo sobre la migración
# Conociendo a los Mosqueros
# Conociendo a los Gorriones
# Conociendo a los Pájaros Carpinteros
# CONSEJOS para Aprender a Observar Aves [Tips para la Observación de las Aves]
# Conociendo a las Aves Playeras
# Conociendo a los Búhos
# Un minuto de aves
# Pajareando en:

# %%
#Ahora aplicando el concocimiento de Pandas generemos un dataFrame con esos elementos
import pandas as pd
dataframe = {'Ids de playlists':playlist_ids,
             'Titulos de playlist':playlist_name,
             'Numero de videos':playlist_noVideos,
             'Miniatura':playlist_pictureStandard,
             'Fecha publicacion':playlist_timepublish}
df = pd.DataFrame(data=dataframe)
df
# Out:
#                       Ids de playlists  \
# 0   PLxZAFzB1EbZaaBOsL2pyDc7jCOiOiTCey
# 1   PLxZAFzB1EbZY0DHDxcj8UcRte9CuqYM30
# 2   PLxZAFzB1EbZaVwUo6N5foohmHNVZ3bbCq
# 3   PLxZAFzB1EbZai_izWRKCAWaOOzt3f9_h0
# 4   PLxZAFzB1EbZbgZOxYdlbx16R79vO6Azjc
# 5   PLxZAFzB1EbZZpaDQBL6LWhCmzXL9qam4-
# 6   PLxZAFzB1EbZa18JnhuJT5CGVYF5qkd1lZ
# 7   PLxZAFzB1EbZY4e9FRlDjLd0zCo0ldb267
# 8   PLxZAFzB1EbZZ6wMbDkUKXPS-z3gT9Zbk0
# 9   PLxZAFzB1EbZa5aZmsMj_lXXwsdD2rpygY
# 10  PLxZAFzB1EbZboAbGpIBs41CFNtTY_fW05
# 11  PLxZAFzB1EbZb4XtfzZg20VyAbqbO_S3O8
# 12  PLxZAFzB1EbZYEmiUWnhDL04n7xypjz2yl
# 13  PLxZAFzB1EbZbOtlVV22wB59w9SuhHcXpG
#
#                                   Titulos de playlist  Numero de videos  \
td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Datos de la duración de los videos

# %%
playlists_total = [] #Guardar la información de cada lista de reproducción
for i in range(0,len(playlist_ids)):
    details_playlist = youtube.playlistItems().list(
        part = 'contentDetails',
        playlistId  = playlist_ids[i], #Pedir los detalles por cada lista.
        maxResults=200 #Maximo de resultados.
    )
    playlistIdResult  = details_playlist.execute() #Hacemos la petición a Google.
    playlists_total.append(playlistIdResult) # agregamos los resultados a la lista.

# %%
for i in range(0,len(playlists_total)):
    for item in playlists_total[i]['items']:
        print(item)
    print()
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'Gr5AI7y9VoSb0GzyVqBHfZ0AMn4', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS5EQUE1NTFDRjcwMDg0NEMz', 'contentDetails': {'videoId': 'jU5IOmPnfLo', 'videoPublishedAt': '2021-07-07T01:00:12Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'jxB2aO0FF3kpbjDIf83QZ5pUnTU', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS40NzZCMERDMjVEN0RFRThB', 'contentDetails': {'videoId': 'bmJpJTJ3VIk', 'videoPublishedAt': '2022-01-16T02:00:12Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'x5HnibVlxwhqZQNlcACLooWA8ws', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS5ENDU4Q0M4RDExNzM1Mjcy', 'contentDetails': {'videoId': 'hfbMEnruecU', 'videoPublishedAt': '2018-01-15T21:53:31Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'P1ZcLc-qIWT5eHQSjurylH8oHms', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS41MzJCQjBCNDIyRkJDN0VD', 'contentDetails': {'videoId': 'xbDM1re1EBs', 'videoPublishedAt': '2023-05-10T03:47:44Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'qnsL5YxElVHzZJqsjy-qZRd5WL8', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS41NkI0NEY2RDEwNTU3Q0M2', 'contentDetails': {'videoId': '9IjA48HruzA', 'videoPublishedAt': '2023-04-15T17:46:02Z'}}
# {'kind': 'youtube#playlistItem', 'etag': '34RImFFYlDZtQWMdxxfF6Uui1_8', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS4wMTcyMDhGQUE4NTIzM0Y5', 'contentDetails': {'videoId': 'OfyZLqUhfk0', 'videoPublishedAt': '2023-03-12T01:20:00Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'uluqGoixzh5NkzIiYSvCMw8Xnjg', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS4xMkVGQjNCMUM1N0RFNEUx', 'contentDetails': {'videoId': 'lzXAFw9WbiE', 'videoPublishedAt': '2022-12-14T17:08:45Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'V9hMov_v_MLduCB_Q2Y7dZvXXAg', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS4yODlGNEE0NkRGMEEzMEQy', 'contentDetails': {'videoId': 'HyyNDAvM3zg', 'videoPublishedAt': '2022-12-07T18:33:56Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'KFEogmgOVdlGRv7R1ES7MWQqAdg', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS41MjE1MkI0OTQ2QzJGNzNG', 'contentDetails': {'videoId': 'a3h5L9DCu9o', 'videoPublishedAt': '2022-09-28T05:00:00Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'rrdko1oZMTf1aD53oeOx366ev1w', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS4wOTA3OTZBNzVEMTUzOTMy', 'contentDetails': {'videoId': 'l8M51-7amRw', 'videoPublishedAt': '2023-02-18T17:00:25Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'gsKVJHwiVH7AX_6PqmRVwTbe1V8', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS45ODRDNTg0QjA4NkFBNkQy', 'contentDetails': {'videoId': 'qkB-4LrJGKo', 'videoPublishedAt': '2022-01-22T14:30:19Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'DXwvyVQMHMKjzBw2tsa8EguXlNY', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS5DQUNERDQ2NkIzRUQxNTY1', 'contentDetails': {'videoId': '7SLK1Gs6_YY', 'videoPublishedAt': '2022-01-08T16:47:20Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'A6dppxB1ExA3XfuRpe2Q3xQCGYE', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS5GNjNDRDREMDQxOThCMDQ2', 'contentDetails': {'videoId': 'KkdQfx9UG8c', 'videoPublishedAt': '2021-12-04T14:52:18Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'vjnW1M9z4gyQqaaP2tqrClzq6w0', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS5EMEEwRUY5M0RDRTU3NDJC', 'contentDetails': {'videoId': 'mo0oltR_keg', 'videoPublishedAt': '2021-10-01T02:42:02Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'ANdGBYoa9IqGZMH4rlJ6V33YDYI', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENleS45NDk1REZENzhEMzU5MDQz', 'contentDetails': {'videoId': 'JPaQotuN7fQ', 'videoPublishedAt': '2021-08-10T15:23:27Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'UhcArWjb7OtLrTkjLdTr6PHQgU8', 'id': 'UEx4WkFGekIxRWJaYWFCT3NMMnB5RGM3akNPaU9pVENle
 'id': 'UEx4WkFGekIxRWJaYk90bFZWMjJ3QjU5dzlTdWhIY1hwRy41MzJCQjBCNDIyRkJDN0VD', 'contentDetails': {'videoId': 'xZPzpAwWQUQ', 'videoPublishedAt': '2021-09-14T22:03:47Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'VVzCYwYhne0Sz6rVIjhcVMORODw', 'id': 'UEx4WkFGekIxRWJaYk90bFZWMjJ3QjU5dzlTdWhIY1hwRy5DQUNERDQ2NkIzRUQxNTY1', 'contentDetails': {'videoId': 'iTLEciMCqAM', 'videoPublishedAt': '2021-10-06T01:00:12Z'}}
# {'kind': 'youtube#playlistItem', 'etag': '-cc_gdy36Fu_YVFkUOW7y8ivenI', 'id': 'UEx4WkFGekIxRWJaYk90bFZWMjJ3QjU5dzlTdWhIY1hwRy45NDk1REZENzhEMzU5MDQz', 'contentDetails': {'videoId': 'Ox_w73mcEps', 'videoPublishedAt': '2021-10-20T01:00:10Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'Di6V8ukCWEEWmKUKp9picfZbNOk', 'id': 'UEx4WkFGekIxRWJaYk90bFZWMjJ3QjU5dzlTdWhIY1hwRy5GNjNDRDREMDQxOThCMDQ2', 'contentDetails': {'videoId': 'nJU-lJtMXxY', 'videoPublishedAt': '2021-10-29T03:30:09Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'iu5xIaopTs76E2ZXhE5rHVhptuQ', 'id': 'UEx4WkFGekIxRWJaYk90bFZWMjJ3QjU5dzlTdWhIY1hwRy40NzZCMERDMjVEN0RFRThB', 'contentDetails': {'videoId': 'Nhnw4mAlRi0', 'videoPublishedAt': '2021-11-25T02:00:11Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'osIhWq-9kOw2bzSmAQnwXsizq-U', 'id': 'UEx4WkFGekIxRWJaYk90bFZWMjJ3QjU5dzlTdWhIY1hwRy5EMEEwRUY5M0RDRTU3NDJC', 'contentDetails': {'videoId': 'YYh71QCSvOg', 'videoPublishedAt': '2022-03-13T02:00:13Z'}}
# {'kind': 'youtube#playlistItem', 'etag': '6EaMWjvXGp6LJtzVs2L6p0GcQxI', 'id': 'UEx4WkFGekIxRWJaYk90bFZWMjJ3QjU5dzlTdWhIY1hwRy45ODRDNTg0QjA4NkFBNkQy', 'contentDetails': {'videoId': '32fhE8Vzgto', 'videoPublishedAt': '2023-01-26T02:00:06Z'}}

# %%
#Veremos que puede ser un poco grande en tener cada lista de producción y sacar
#el tiempo de reproducción manualmente por cada lista. Para solucionar este
#problema usaremos listas vacias en listas vacias, es decir, generaremos listas
#vacias entro de una lista ¿Cuántas listas vacias? Será por cada lista de reproduccion.
#El resultado son listas vacias que almacenaremos los ids de los videos por
#cada lista de reproducción
rangePlayList = [[] for _ in range(0,len(playlists_total))]
rangePlayList
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], []]

# %%
#Ahora almacenaremos los elementos en cada lista vacia.
for i in range(0,len(playlists_total)):
    for item in playlists_total[i]['items']:
        vd = item['contentDetails']['videoId']
        if i==i:
            rangePlayList[i].append(vd)
rangePlayList#Lista de ids por lista de reproduccion
# Out:
# [['jU5IOmPnfLo',
#   'bmJpJTJ3VIk',
#   'hfbMEnruecU',
#   'xbDM1re1EBs',
#   '9IjA48HruzA',
#   'OfyZLqUhfk0',
#   'lzXAFw9WbiE',
#   'HyyNDAvM3zg',
#   'a3h5L9DCu9o',
#   'l8M51-7amRw',
#   'qkB-4LrJGKo',
#   '7SLK1Gs6_YY',
#   'KkdQfx9UG8c',
#   'mo0oltR_keg',
#   'JPaQotuN7fQ',
#   '6S-3rh35Ewk',
#   'MWXhTLj_QHU',
#   '0rnNUobbgA8',
#   'KOAyxWrap1Y',
#   'Vo6Gbra8db4',
#   'uecP1pLVXxc'],
#  ['RN6un44Z0HA',
#   'tmKu78ukBTY',
#   'ThwL33jFFuU',
#   '0y6t1bJld3A',
#   'wDwuyytCHKQ',
#   'FmA36NJf21A',
#   'DR54BE33IUA',
#   'l0izZoaguAo',
#   '1QHZbfRES_A',
#   'K8gas4n--3I',
#   'kmQxDOtvqPE',
#   'tnk83rVjkuY',
#   'GMSxD8Nb3m0'],
#  ['OikYK0QCnnk',
#   'hgclq1yCdAA',
#   'CnXrFoNHBPg',
#   'DBXLZgi0tTk',
#   'nuhZByxVQHo',
#   '6JkTovk2gM4',
#   'P6XQF9xoxyc',
#   'tgicKJVHfQQ',
#   '26R5T1P8oeM',
#   'JkpGWmeE3BA',
#   '7xzINoGBHfk',
#   'iLL8EUBen4k',
#   'ZILNrg1JPz8'],
#  ['dZgbzB1AbiQ',
#   'NLpY2-gW2XM',
#   'zEmfaQrY_7A',
#   'SO59R7wxGAA',
#   'GE3kVPzVUlc',
#   'VnYLEDqStHY',
#   'L9olNxEtsso',
#   'oMlp4cJtMs0',
#   'CxabndOvUNc',
#   'N6oGQIIq5DQ',
#   'Okcxym67zzs',
#   'csj8t4kARHY',
#   'sYvaazIkaRo',
#   'Zcp3NfDYGx0',
#   'SLnDtSSd2G0',
#   '1zmf4-fnTc4',
#   'aeIwnzsufKk',
#   '7LyWmOeDpdQ'],
#  ['7yIggKQF6SQ',
#   'RTGLaGw93OM',
#   'hfn8ZLPzJwo',
#   'z1wgZ8p0XjM',
#   'h_m4kGEKqc0',
#   'MtO-EAfshtY',
#   '-1vnGFKriSo',
#   'EY3i6jf-uwg',
#   '82bcbIrLzcg',
#   'RXbyXD60ZAk',
#   'O4W93-HTNt0',
#   'o6bGJ8yfx2g',
#   '18h3jC0oBgg',
#   'Ug4wMOFAIEY',
#   'y2bocdoybd0',
#   'bA8ELskKN8w',
#   'COmQgnjHVaw',
#   '-FqK1CG0oA0',
#   'zEiI_QVZKGI',
#   'rdrIJq1-sv8',
#   'yAfnMgi6tiw',
#   'Xz5KbQq4rRA',
#   'p1YDEhRwr7U',
#   '36OpeEqSTD0',
#   'M2hZCS98ocg',
#   'zjGrCLanVTs',
#   'YeuXlxiBOhg',
#   'hX6xgJmcC9U',
#   'xYMmP_YCBao',
#   'GddkgAzRveg',
#   '0R84MEkpFeA',
#   'YuBfF6ZNl3I',
#   'j3JbW7ty5AY',
#   'JkpGWmeE3BA',
#   '17xYW1mQl_o',
#   'SC9np_DCi_k',
#   'eQEnxa_ANa8',
#   'z7hY3TrOEvo',
#   'Z6nJ5NWKPCg',
#   'YmjhRgex6N8',
#   's9tRXGbKWCM',
#   'DaB32PimWgw',
#   'zCXODKd0yqA',
#   '-dTIHprS9lU',
#   'eWrROHhlaJQ',
#   'i9jJ5HTfg1o',
#   'ToU2LCPa-YE',
#   'WKEm2WKZ7mU',
#   'zw_A-8ms5Q4',
#   'rKZcoMJtQlI'],
#  ['BOBPnuyRpnU',
#   'fvxwKDsr5D8',
#   'u71Z3MaOvl4',
#   'rlxLjg40h1I',
#   'QhX4hYCOoJw',
#   'My5QvNLEDcY'],
#  ['oW7CGnLH3cM',
#   'sAyPicL2D3Y',
#   'uEg2ODMIXI0',
#   '19EaZ8IFtNQ',
#   'PJomsN-hZ2w',
#   'ZB1LVuhSkt8',
#   'wMWYpBaeWNM',
#   'IN1Vd0DHdu8',
#   'XsXTfQy4lwA',
#   'YzboYnehhvw',
#   'tQoInmeLRm8',
#   'QeF9ZtlY8VU',
#   'EyicbEQPAaM',
#   'M6AujIoF47w',
#   'JrySPE8Zfak',
#   'tQoInmeLRm8',
#   'HMsuR1T0h8Q'],
#  ['uEvzPjNUGMc',
#   'IMViMwkNc34',
#   '3Tl_PjFLtrY',
#   '5HYKpV1E2v8',
#   'ilLp-iA89o0',
#   'Fn5GJp45qgc',
#   '5MZ6z2mL114',
#   'I7fI5HdqGcE',
#   'bzpMJ11MJcw',
#   '4gbPsFYUe50'],
#  ['F0ri6AoFNkc',
#   'H6eJoAXOJLU',
#   'kncG8S3tsQA',
#   'pjMIWk4uzcI',
#   'TAmK6WhastU',
#   'nNZwvA4dgUQ',
#   'V-fzeJiJNTg',
#   'VLY8rVIAtE8',
#   'v1Dvd8iwgKM',
#   'r0P9btGTxcE'],
#  ['UejlJwt9zWM',
#   'clU2EbKAuTg',
#   'SRGmzxC-FYI',
#   'RN6un44Z0HA',
#   'ohCqHG-POcY',
#   'kHSYE7Te_8U',
#   'jD_ltjiXm2Q',
#   'acaYPEO71CA',
#   'bmJpJTJ3VIk',
#   'x5bNEETEbLQ',
#   'xyUNE1y5Jvs'],
#  ['QhX4hYCOoJw',
#   'Ebb7-6mMCTQ',
#   'XFEJB6TJqHM',
#   '3YoTFDycihM',
#   'wYWtWEOfQjc',
#   'OloX04oyoVU',
#   'K98Shx2tDrc',
#   'bg3lO-xwy0Q',
#   'j8SgzLRcm9o',
#   'lGtKXat1VSo',
#   'qA2GqIvAhGQ',
#   'to8HYA_egA4',
#   'DE9J_vk4yg0',
#   '9j-WDR3Gfds',
#   'mVpDHClPm-U',
#   '041QL7E9QSc',
#   'lruUPnsitGw',
#   'giB50Oa56D0',
#   'kPpphaZKBNo',
#   '3kW-3R1Cci0',
#   'bujD9xADqDo',
#   '7tvwNyQ_1x8',
#   'h_4jTDGkBX8',
#   'GyAdoXcESro',
#   'Nj6sWTB-ZXc',
#   'wmkrGK2vHT8',
#   'VszJQg2DgpE'],
#  ['Bg5l8ax7Kfc',
#   'fJEhg99MdWo',
#   'EflK9eG6vNI',
#   '-_P9QuPSMGE',
#   '1pMq9STAshI',
#   'snUhwVtupFc',
#   'Qdrqzp5oG4Q',
#   'XDeTgDgCUQM',
#   'mjo8mhBqYOo',
#   'zXtIelgGj3I',
#   '0GwURl-Atb0',
#   'iE0Rkd3Rf8g',
#   '5If8mfLQYsA',
#   'Z1mzWw2I3Js'],
#  ['uEvzPjNUGMc',
#   'ZILNrg1JPz8',
#   'twVJXQ6H9sI',
#   'fF23fJOiZJA',
#   'Z1mzWw2I3Js',
#   '5If8mfLQYsA',
#   'iE0Rkd3Rf8g',
#   '7LyWmOeDpdQ',
#   'GyAdoXcESro',
#   'Nj6sWTB-ZXc',
#   'wmkrGK2vHT8',
#   'VszJQg2DgpE',
#   'ysRdNixTMs8',
#   '1zmf4-fnTc4',
#   'uecP1pLVXxc',
#   '8LFcUSBNmYQ',
#   'PT1aDyGGSiQ',
#   'ZYHZWMx4M08',
#   'PCR5etmiMQI',
#   'vODQH-4BX2s',
#   '5eLdess5q1o',
#   'qThpyKNcOfM',
#   'xbDM1re1EBs',
#   'L-GfVuTyETU',
#   'k-K_muljDac',
#   'pg_Ydlr0sJY',
#   '9IjA48HruzA',
#   'sO_NGIeM4F8',
#   'OfyZLqUhfk0',
#   'GXdNeUfJ7Rk',
#   'wr7DGhPDiyw',
#   'o-OEljjqldc',
#   'E9Z7y4AsCIY',
#   'l8M51-7amRw',
#   'wCU7Zs4H_aI',
#   '8a_6YTdUJYM',
#   'r0P9btGTxcE',
#   'SLnDtSSd2G0',
#   'TVaK4p-na8M',
#   'zXtIelgGj3I',
#   '7PjYdQtITMs',
#   'P72cTOr_Cy0',
#   'lzXAFw9WbiE',
#   'HyyNDAvM3zg',
#   'Zcp3NfDYGx0',
#   '0IxXmBBAAsc',
#   'tQoInmeLRm8',
#   'QeF9ZtlY8VU',
#   'EyicbEQPAaM',
#   'M6AujIoF47w'],
#  ['VQs3XW8E_NI',
#   '2lxV7W3njUE',
#   'pnQzFEpqTts',
#   'jhqpM-RTLvk',
#   'uU1lSY7IODs',
#   'eIUYrl8pKVc',
#   'xZPzpAwWQUQ',
#   'iTLEciMCqAM',
#   'Ox_w73mcEps',
#   'nJU-lJtMXxY',
#   'Nhnw4mAlRi0',
#   'YYh71QCSvOg',
#   '32fhE8Vzgto']]

# %%
#Definamos ahora una función para que sea más efectivo en que nos regrese los
#detalles de cada video por cada lista de reproducción y solamente la llamemos
#cuando sea necesario hacer una petición a Google.
def videos_reponse(id_videos):
    video_request  = youtube.videos().list(
        part='contentDetails',
        id=','.join(id_videos)
    )
    video_data = video_request.execute()
    return video_data #Regresa la información de cada video usando su id

# %%
playlist1_videos = videos_reponse(rangePlayList[0]) #En este ejemplo es para la lista 1 y sus videos
playlist2_videos = videos_reponse(rangePlayList[1]) #En este para la lista 2 y sus ejemplos
for item in playlist1_videos['items']:
    duration = item['contentDetails']['duration']
    print(duration)#Formato de Youtube será la duración que veremos que nos da un formato no reconocible
    print()
# Out:
# PT29M
#
# PT14M52S
#
# PT9M49S
#
# PT3M15S
#
# PT4M7S
#
# PT3M39S
#
# PT4M25S
#
# PT3M12S
#
# PT3M8S
#
# PT3M28S
#
# PT3M22S
#
# PT3M19S
#
# PT3M45S
#
# PT3M
#
# PT3M15S
#
# PT3M8S
#
# PT2M36S
#
# PT2M9S
#
# PT1M35S
#
# PT1M23S
#
# PT4M48S

# %%
#Aquí empezaremos a hablar de Expresiones Regulares
#Dejaré aquí la documentación correspondiente.
#https://docs.python.org/es/3/howto/regex.html
import re
hours_re = re.compile(r'(\d+)H')
minuntes_re = re.compile(r'(\d+)M')
seconds_re = re.compile(r'(\d+)S')
for item in playlist1_videos['items']:
    duration = item['contentDetails']['duration']
    horas = hours_re.search(duration)
    minutos = minuntes_re.search(duration)
    segundos = seconds_re.search(duration)
    print(horas,minutos,segundos)
    print()
# Out:
# None <re.Match object; span=(2, 5), match='29M'> None
#
# None <re.Match object; span=(2, 5), match='14M'> <re.Match object; span=(5, 8), match='52S'>
#
# None <re.Match object; span=(2, 4), match='9M'> <re.Match object; span=(4, 7), match='49S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='15S'>
#
# None <re.Match object; span=(2, 4), match='4M'> <re.Match object; span=(4, 6), match='7S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='39S'>
#
# None <re.Match object; span=(2, 4), match='4M'> <re.Match object; span=(4, 7), match='25S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='12S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 6), match='8S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='28S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='22S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='19S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='45S'>
#
# None <re.Match object; span=(2, 4), match='3M'> None
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 7), match='15S'>
#
# None <re.Match object; span=(2, 4), match='3M'> <re.Match object; span=(4, 6), match='8S'>
#
# None <re.Match object; span=(2, 4), match='2M'> <re.Match object; span=(4, 7), match='36S'>
#
# None <re.Match object; span=(2, 4), match='2M'> <re.Match object; span=(4, 6), match='9S'>
#
# None <re.Match object; span=(2, 4), match='1M'> <re.Match object; span=(4, 7), match='35S'>
#
# None <re.Match object; span=(2, 4), match='1M'> <re.Match object; span=(4, 7), match='23S'>
#
# None <re.Match object; span=(2, 4), match='4M'> <re.Match object; span=(4, 7), match='48S'>

# %%
#Cuando ejecutamos la celda de arriba veremos que tenemos en match = 'H'
#minutos y finalmente los segundos pero seguimos teniendo el problema en
#poder visualizarlo de manera más con detalle
#Para ello vamos a arreglar este for usando métodos que si no hay horas
#o minutos (pueden ser una lista de shorts) regrese un 0
for item in playlist1_videos['items']:
    duration = item['contentDetails']['duration']
    horas = hours_re.search(duration)
    minutos = minuntes_re.search(duration)
    segundos = seconds_re.search(duration)
    #Si no tenemos horas o minutos extensos
    horas = int(horas.group(1)) if horas else 0
    minutos = int(minutos.group(1)) if minutos else 0
    segundos = int(segundos.group(1)) if segundos else 0
    print(horas,minutos,segundos)
    print()
# Out:
# 0 29 0
#
# 0 14 52
#
# 0 9 49
#
# 0 3 15
#
# 0 4 7
#
# 0 3 39
#
# 0 4 25
#
# 0 3 12
#
# 0 3 8
#
# 0 3 28
#
# 0 3 22
#
# 0 3 19
#
# 0 3 45
#
# 0 3 0
#
# 0 3 15
#
# 0 3 8
#
# 0 2 36
#
# 0 2 9
#
# 0 1 35
#
# 0 1 23
#
# 0 4 48

# %%
#Veremos que es un poco más entendible pero ahora no es tan claro.
#Vemos que tenemos que hacer esto por cada lista de reproducción,
#hagamos esto para n-videos. Definiremos una funcion de nos regrese
#el tiempo en formato de tiempo o la reproducción entre los segundos
#totales,es decir, si en una lista hay dos videos de 1hr entonces regre-
#sará 7200 segundos.
from datetime import timedelta #Transformar tiempo a segundos
def timevideosPlaylist(playlist):
    time_videos = []#Tiempo de cada video por cada lista de reproduccion.

    for item in playlist['items']:
        duration = item['contentDetails']['duration']
        horas = hours_re.search(duration)
        minutos = minuntes_re.search(duration)
        segundos = seconds_re.search(duration)
        horas = int(horas.group(1)) if horas else 0
        minutos = int(minutos.group(1)) if minutos else 0
        segundos = int(segundos.group(1)) if segundos else 0
        #Por cada video
        video_segundos = timedelta(
            hours = horas,
            minutes = minutos,
            seconds = segundos
        ).total_seconds()
        #Por cada video de la lista de reproduccion
        time_videos.append(video_segundos)
    total_reproduction = int(sum(time_videos))
    minutos,segundos =divmod(total_reproduction,60)
    horas,minutos = divmod(minutos,60)
    total_reproduction = f'{horas}:{minutos}:{segundos}' #Formato H:M:S
    return [time_videos,total_reproduction]

timevideosPlaylist(playlist2_videos) #Tenemos resultados para la segunda lista de reproduccion para cada n-video.
# Out:
# [[1325.0,
#   752.0,
#   1334.0,
#   1106.0,
#   1032.0,
#   1021.0,
#   1047.0,
#   880.0,
#   1451.0,
#   637.0,
#   651.0,
#   937.0,
#   1096.0],
#  '3:41:9']

# %%
#Obtengamos la suma de cada lista resproducción con todos los videos usando la
#función que vimos arriba y aplicando esta función que nos resgresará una lista
#y cada elemento será en formato de hora de cada lista de reproducción en el canal
def timeStreamingChannels(listaTotales):
    timeStreaming_seconds = []
    for item in listaTotales:
        plt= videos_reponse(item)
        time = timevideosPlaylist(plt)[1] #Obtenemos el formato de hora.
        timeStreaming_seconds.append(time)
    return timeStreaming_seconds
timeStreamingChannels(rangePlayList) #Lo usamos para toda la lista de reproducciones del canal
# Out:
# ['1:51:15',
#  '3:41:9',
#  '2:52:44',
#  '2:47:49',
#  '62:26:29',
#  '1:13:26',
#  '1:4:59',
#  '0:22:53',
#  '0:55:42',
#  '3:18:34',
#  '1:45:26',
#  '1:34:19',
#  '3:8:20',
#  '2:47:30']

# %%
#Finalmente volveremos a correr el código  y añadiendo una columna donde podamos
#visualizar el tiempod de duración de cada lisa de reproducción en total
duration = timeStreamingChannels(rangePlayList)
df['Duracion'] = duration #Agregamos una nueva columna con los datos al dataFrame
from IPython.core.display import HTML
def a_img_tg(url):
    return '<img src="'+ url + '" width="175" >'
display(HTML(df.to_html(escape=False,formatters=dict(Miniatura=a_img_tg))))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ids de playlists</th>
#       <th>Titulos de playlist</th>
#       <th>Numero de videos</th>
#       <th>Miniatura</th>
#       <th>Fecha publicacion</th>
#       <th>Duracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PLxZAFzB1EbZaaBOsL2pyDc7jCOiOiTCey</td>
#       <td>Conociendo a los Colibríes</td>
#       <td>21</td>
#       <td><img src="https://i.ytimg.com/vi/jU5IOmPnfLo/sddefault.jpg" width="175" ></td>
#       <td>2023-05-15 09:14:23</td>
#       <td>1:51:15</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>PLxZAFzB1EbZY0DHDxcj8UcRte9CuqYM30</td>
#       <td>Binoculares para la observación de aves - La Mochila Pajarera</td>
#       <td>13</td>
#       <td><img src="https://i.ytimg.com/vi/RN6un44Z0HA/sddefault.jpg" width="175" ></td>
#       <td>2022-01-04 03:24:22</td>
#       <td>3:41:9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>PLxZAFzB1EbZYEmiUWnhDL04n7xypjz2yl</td>
#       <td>Un minuto de aves</td>
#       <td>199</td>
#       <td><img src="https://i.ytimg.com/vi/uEvzPjNUGMc/sddefault.jpg" width="175" ></td>
#       <td>2018-02-18 02:57:10</td>
#       <td>3:8:20</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>PLxZAFzB1EbZbOtlVV22wB59w9SuhHcXpG</td>
#       <td>Pajareando en:</td>
#       <td>13</td>
#       <td><img src="https://i.ytimg.com/vi/VQs3XW8E_NI/sddefault.jpg" width="175" ></td>
#       <td>2017-12-26 03:53:54</td>
#       <td>2:47:30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Encontrando los videos con más likes

# %%
#Vamos a definir las dos funciones faltantes para obtener este resultado.
#La primera nos hará la petición por cada video de sus estadísticas y propiedades de
#estilo o dieseño. La segundo será para obtener los likes en los videos.

#Estadisticas por cada video
def stadistics_video(id_videos):
    video_request  = youtube.videos().list(
        part='statistics,snippet',
        id=','.join(id_videos)
    )
    video_data = video_request.execute()
    return video_data
#Solucion por decorador
def likesvideos_per_playlist(function):
    video_view = []#Tiempo de cada video por cada lista de reproduccion.
    for item in function['items']:
        likes = item['statistics']['likeCount'] #Likes de videos
        video_id = item['id'] #Id del video
        name_video = item['snippet']['title'] #Titulo el video
        yt_link = f'https://youtu.be/{video_id}'#Link del video
        video_view.append({'title':name_video,
                            'likeCount':int(likes),
                           'url':yt_link}) #Diccionario donde se almacen los datos anteriores
    video_view.sort(key=lambda vid:vid['likeCount'],reverse=True) #Este método lo que hacemos es ordenarlos de mayor a menor todos sus elementos
    return video_view #Retornamos el diccionario con los videos ordenados con mayores likes por cada lista de reproducción

# %%
pl1_staditic  = stadistics_video(rangePlayList[0])
view_plst = likesvideos_per_playlist(pl1_staditic)

# %%
#Si nos damos cuenta de algo, es que como regrese un diccionario podemos jugar
#con los indices obteniendo los likes, el link y titulo como podemos ver aquí
view_plst[12]['likeCount'],view_plst[12]['url'],view_plst[12]['title']
# Out:
# (87,
#  'https://youtu.be/uecP1pLVXxc',
#  'El misterioso Ermitaño de la selva | #UnMinutodeAves No.183')

# %%
#Vamos organizarlo de una manera mejor y finalmente que quede indexado en nuetro dataframe
def mostPopularSongbyPL(listasCanal):
    name_popularvid = [] #Lista de los videos más populares
    liked_list = [] #Lista de likes
    url_list = [] #Urls de los videos
    noneHit = None #En el caso que no hubiera información de ello
    for i in listasCanal:
        staditica = stadistics_video(i) #Llamamos la función de arriba
        try: #Si hay elementos disponibles llenamos las listas
            liked = likesvideos_per_playlist(staditica)
            name_popularvid.append(liked[0]['title'])
            liked_list.append(liked[0]['likeCount'])
            url_list.append(liked[0]['url'])
        except:# En el caso que no hubiera un elemento(s) para tratar ese error se hará listas nulas como se observará
            name_popularvid.append(noneHit)
            liked_list.append(noneHit)
            url_list.append(noneHit)
    return [name_popularvid,liked_list,url_list] #Regresamos los nombres,likes y las urls de los videos
mostPopularSongbyPL(rangePlayList)
# Out:
# [['Colibríes | Entre la guerra y las flores',
#   'Aprendiendo a Observar Aves 1.4 | Usando Binoculares + Review de modelos',
#   'La alucinante historia del Chipe Rojo',
#   'Águila Arpía | La Reina de la Selva',
#   'Hablemos de aves 59 no se de que hablar hoy, vengo llegando de pajarear',
#   'Aves Playeras | Las Reinas de la Migración',
#   'La tierra de los Tiranos | La incomprensible historia de los mosqueros',
#   'Un Minuto de Aves #73 Gorrión Serrano',
#   'Carpintero Imperial | El último de los gigantes',
#   'Aprendiendo a observar aves 1.2 | ¿Cómo las identifico? parte 1',
#   'Aves Playeras | Las Reinas de la Migración',
#   'Búhos y Lechuzas|¿Acaso son diferentes?',
#   '¿es esta el ÁGUILA de la bandera 🇲🇽? | #UnMinutodeAves No. 189',
#   'Pajareando en: Península de Yucatán'],
#  [504, 696, 258, 623, 92, 250, 200, 130, 1136, 805, 250, 577, 129, 608],
#  ['https://youtu.be/jU5IOmPnfLo',
#   'https://youtu.be/RN6un44Z0HA',
#   'https://youtu.be/26R5T1P8oeM',
#   'https://youtu.be/dZgbzB1AbiQ',
#   'https://youtu.be/yAfnMgi6tiw',
#   'https://youtu.be/QhX4hYCOoJw',
#   'https://youtu.be/oW7CGnLH3cM',
#   'https://youtu.be/4gbPsFYUe50',
#   'https://youtu.be/VLY8rVIAtE8',
#   'https://youtu.be/clU2EbKAuTg',
#   'https://youtu.be/QhX4hYCOoJw',
#   'https://youtu.be/fJEhg99MdWo',
#   'https://youtu.be/7LyWmOeDpdQ',
#   'https://youtu.be/2lxV7W3njUE']]

# %%
#Para visualizar los links se puedan dar click a que hacer una pequeña modificacion
#Pero primero indexamos los elementos al dataFrame que teníamos
df['Nombre de Hit'],df['Likes'],df['UrlHit'] = mostPopularSongbyPL(rangePlayList)[0],mostPopularSongbyPL(rangePlayList)[1],mostPopularSongbyPL(rangePlayList)[2]
display(HTML(df.to_html(escape=False,render_links=True,formatters=dict(Miniatura=a_img_tg)))) #render_links = True lo permite.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ids de playlists</th>
#       <th>Titulos de playlist</th>
#       <th>Numero de videos</th>
#       <th>Miniatura</th>
#       <th>Fecha publicacion</th>
#       <th>Duracion</th>
#       <th>Nombre de Hit</th>
#       <th>Likes</th>
#       <th>UrlHit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PLxZAFzB1EbZaaBOsL2pyDc7jCOiOiTCey</td>
#       <td>Conociendo a los Colibríes</td>
#       <td>21</td>
#       <td><img src="https://i.ytimg.com/vi/jU5IOmPnfLo/sddefault.jpg" width="150" ></td>
#       <td>2023-05-15 09:14:23</td>
#       <td>1:51:15</td>
#       <td>Colibríes | Entre la guerra y las flores</td>
#       <td>504</td>
#       <td><a href="https://youtu.be/jU5IOmPnfLo" target="_blank">https://youtu.be/jU5IOmPnfLo</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>PLxZAFzB1EbZY0DHDxcj8UcRte9CuqYM30</td>
#       <td>Binoculares para la observación de aves - La Mochila Pajarera</td>
#       <td>13</td>
#       <td><img src="https://i.ytimg.com/vi/RN6un44Z0HA/sddefault.jpg" width="150" ></td>
#       <td>2022-01-04 03:24:22</td>
#       <td>3:41:9</td>
#       <td>Aprendiendo a Observar Aves 1.4 | Usando Binoculares + Review de modelos</td>
#       <td>696</td>
#       <td><a href="https://youtu.be/RN6un44Z0HA" target="_blank">https://youtu.be/RN6un44Z0HA</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td